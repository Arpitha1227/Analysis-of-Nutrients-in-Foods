# %% [markdown]
# ## Data Dictionary
# 1. NDB_No - Nutrition database number
# 2. Shrt_Desc - Short description
# 3. Water_(g) - water in grams per 100 grams
# 4. Energ_Kcal - Energy in Kcal
# 5. Protein_(g) - Protein
# 6. LipidTot(g) - Total Lipid
# 7. Ash_(g) - Ash
# 8. Carbohydrt_(g) - Carbohydrate, by difference
# 9. FiberTD(g) - Fiber, total dietary
# 10. SugarTot(g) - Total Sugars
# 11. Calcium_(mg) - Calcium
# 12. Iron_(mg) - Iron
# 13. Magnesium_(mg) - Magnesium
# 14. Phosphorus_(mg) - Phosphorus
# 15. Potassium_(mg) - Potassium
# 16. Zinc_(mg) - Zinc
# 17. Copper_(mg) - Copper
# 18. Manganese_(mg) - Manganese
# 19. Selenium_(æg) - Selenium
# 20. Sodium_(mg) - Sodium

# %%
#Import all the necessary modules
import pandas as pd
import numpy as np
import os

# %%
#Load the Data file into Python DataFrame using pandas read_excel method
df = pd.read_excel("Food_Nutrition.xlsx")

# %%
#Using the Head function to view the top records
df.head(10)
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
# 5    1006             CHEESE,BRIE      48.42         334        20.75
# 6    1007        CHEESE,CAMEMBERT      51.80         300        19.80
# 7    1008          CHEESE,CARAWAY      39.28         376        25.18
# 8    1009          CHEESE,CHEDDAR      37.02         404        22.87
# 9    1010         CHEESE,CHESHIRE      37.65         387        23.37
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# ...

# %%
#Using the Tail function to view the last records
df.tail(5)
# Out:
#      NDB_No                                          Shrt_Desc  Water_(g)  \
# 595    3949  INF FORMULA, ABBOTT NUTR, SIMILAC, ADVANCE, W/...      87.79
# 596    3950  INF FORMULA,ABBOTT NUTR,SIMILAC,ADVANC,W/ IRON...       2.25
# 597    3951  INF FORMU,ABBO NUTR,SIMILAC,ADVAN,W/ IRON,LIQ ...      76.16
# 598    3952  INF FORMULA, ABB NUTR, SIMIL, ISOMIL, ADVA W/ ...      75.81
# 599    3953  INF FORMULA, ABBO NUTR,SIMIL,ISOMIL, ADVANCE W...      87.54
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 595          66         1.36           3.70     0.38            6.77
# 596         522        10.89          28.87     3.26           54.73
# 597         127         2.64           6.89     0.79           13.52
# 598         128         3.13           6.98     0.88           13.21
# 599          66         1.61           3.59     0.66            6.70
#
#      Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  Iron_(mg)  Magnesium_(mg)  \
# ...

# %%
#Using Shape to find the number of Rows and columns in the Dataframe
df.shape
# Out:
# (600, 20)

# %%
print("The number of rows are ",df.shape[0],"\n","The number of columns are",df.shape[1])
# Out:
# The number of rows are  600
#  The number of columns are 20

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# NDB_No             0
# Shrt_Desc          0
# Water_(g)          0
# Energ_Kcal         0
# Protein_(g)        0
# Lipid_Tot_(g)      1
# Ash_(g)            1
# Carbohydrt_(g)     0
# Fiber_TD_(g)       0
# Sugar_Tot_(g)      0
# Calcium_(mg)       0
# Iron_(mg)          0
# Magnesium_(mg)     0
# Phosphorus_(mg)    0
# Potassium_(mg)     0
# Sodium_(mg)        0
# Zinc_(mg)          0
# Copper_mg)         0
# Manganese_(mg)     0
# Selenium_(µg)      0
# dtype: int64

# %%
#Dropping missing values
df=df.dropna()

# %%
#Rechecking for missing values
df.isnull().sum()
# Out:
# NDB_No             0
# Shrt_Desc          0
# Water_(g)          0
# Energ_Kcal         0
# Protein_(g)        0
# Lipid_Tot_(g)      0
# Ash_(g)            0
# Carbohydrt_(g)     0
# Fiber_TD_(g)       0
# Sugar_Tot_(g)      0
# Calcium_(mg)       0
# Iron_(mg)          0
# Magnesium_(mg)     0
# Phosphorus_(mg)    0
# Potassium_(mg)     0
# Sodium_(mg)        0
# Zinc_(mg)          0
# Copper_mg)         0
# Manganese_(mg)     0
# Selenium_(µg)      0
# dtype: int64

# %%
#Five-point summary
df.describe()
# Out:
#             NDB_No   Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count   598.000000  598.000000  598.000000   598.000000     598.000000
# mean   2305.448161   60.415870  186.521739     8.640385       8.849649
# std    1081.807819   31.929817  158.540534    10.939719      12.262311
# min    1001.000000    0.200000    0.000000     0.000000       0.000000
# 25%    1173.250000   39.167500   63.000000     1.702500       0.697500
# 50%    2052.500000   76.180000  106.000000     3.900000       3.475000
# 75%    3190.750000   85.987500  314.500000    12.385000      13.000000
# max    3953.000000   99.900000  876.000000    84.080000      99.480000
#
#           Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  598.000000      598.000000    598.000000     598.000000     598.00000
# mean     2.542040       19.395920      2.587458       9.122726     262.01505
# std      6.494483       21.522166      7.594803      13.927320     376.94743
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 598 entries, 0 to 599
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NDB_No           598 non-null    int64
#  1   Shrt_Desc        598 non-null    object
#  2   Water_(g)        598 non-null    float64
#  3   Energ_Kcal       598 non-null    int64
#  4   Protein_(g)      598 non-null    float64
#  5   Lipid_Tot_(g)    598 non-null    float64
#  6   Ash_(g)          598 non-null    float64
#  7   Carbohydrt_(g)   598 non-null    float64
#  8   Fiber_TD_(g)     598 non-null    float64
#  9   Sugar_Tot_(g)    598 non-null    float64
#  10  Calcium_(mg)     598 non-null    int64
#  11  Iron_(mg)        598 non-null    float64
#  12  Magnesium_(mg)   598 non-null    int64
#  13  Phosphorus_(mg)  598 non-null    int64
#  14  Potassium_(mg)   598 non-null    int64
#  15  Sodium_(mg)      598 non-null    int64
# ...

# %%
#Using shape to check the dimension of the dataframe
df.shape
# Out:
# (598, 20)

# %%
# Creating a vector “test” using the top 10 values of variable Protein_(g) since it is a crucial macronutrient
test=df['Protein_(g)'].head(10)
test
# Out:
# 0      0.85
# 1      0.49
# 2      0.28
# 5     20.75
# 6     19.80
# 7     25.18
# 8     22.87
# 9     23.37
# 10    23.76
# 11    11.12
# Name: Protein_(g), dtype: float64

# %%
# Selecting the frst 5 rows of initial 5 variables in a matrix format
df.iloc[0:5, 0:5]
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 5    1006             CHEESE,BRIE      48.42         334        20.75
# 6    1007        CHEESE,CAMEMBERT      51.80         300        19.80

# %%
# Creating a new variable “EPW” by dividing Energ_Kcal with the Protein and finding the dimesnsion of the same
df['EPW']=df['Energ_Kcal']/df['Protein_(g)']

# %%
df.head(5)
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 5    1006             CHEESE,BRIE      48.42         334        20.75
# 6    1007        CHEESE,CAMEMBERT      51.80         300        19.80
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          78.30     1.62            2.87           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 5          27.68     2.70            0.45           0.0           0.45  ...
# 6          24.26     3.68            0.46           0.0           0.46  ...
#
#    Iron_(mg)  Magnesium_(mg)  Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  \
# ...

# %%
# Creating a subset of the dataset, where the Energ_Kcal is less than 500 calories and checking the dimension
df_new=df[df['Energ_Kcal']<500]

# %%
#Here we have 36 less rows than originally where Energ_Kcal>500 calories
df_new.shape
# Out:
# (562, 21)

# %%
# Finding the top 10 products based on the criteria of - Higher the Energy_Kcal = Higher the ranking
df.sort_values(by='Energ_Kcal',ascending = False).head(10)
# Out:
#      NDB_No                             Shrt_Desc  Water_(g)  Energ_Kcal  \
# 2      1003                  BUTTER OIL,ANHYDROUS       0.24         876
# 1      1002                BUTTER,WHIPPED,W/ SALT      16.72         718
# 0      1001                      BUTTER,WITH SALT      15.87         717
# 131    1145                   BUTTER,WITHOUT SALT      17.94         717
# 125    1137                        EGG,YOLK,DRIED       3.08         669
# 122    1134  EGG,WHL,DRIED,STABILIZED,GLUCOSE RED       1.87         615
# 121    1133                         EGG,WHL,DRIED       2.78         592
# 63     1070              DESSERT TOPPING,POWDERED       1.47         577
# 178    1210                    EGG MIX,USDA CMDTY       2.78         555
# 62     1069             CREAM SUBSTITUTE,POWDERED       2.98         529
#
#      Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 2           0.28          99.48     0.00            0.00           0.0
# ...

# %%
#Lower the Protein content = Lower the ranking
df.sort_values(by='Protein_(g)',ascending = False).head(10)
# Out:
#      NDB_No                                      Shrt_Desc  Water_(g)  \
# 216    1258         EGG,WHITE,DRIED,STABILIZED,GLUCOSE RED       5.48
# 124    1136     EGG,WHITE,DRIED,PDR,STABILIZED,GLUCOSE RED       8.54
# 151    1173                                EGG,WHITE,DRIED       5.80
# 123    1135  EGG,WHITE,DRIED,FLAKES,STABILIZED,GLUCOSE RED      14.62
# 130    1144                          EGG SUBSTITUTE,POWDER       3.86
# 191    1224       PROTEIN SUPP,MILK BSD,MUSCLE MILK LT,PDR      12.00
# 122    1134           EGG,WHL,DRIED,STABILIZED,GLUCOSE RED       1.87
# 121    1133                                  EGG,WHL,DRIED       2.78
# 190    1223          PROTEIN SUPP,MILK BSD,MUSCLE MILK,PDR      15.00
# 159    1185                  PARMESAN CHS TOPPING,FAT FREE       8.60
#
#      Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 216         357        84.08           0.32     5.61            4.51
# ...

# %%
#Create a subset of the data where product_desc contains “CHEESE” and list down the summary statistics of the subset
df_cheese= df[df['Shrt_Desc'].str.contains("CHEESE")]

# %%
df_cheese.shape
# Out:
# (74, 21)

# %%
df_cheese.describe()
# Out:
#             NDB_No  Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count    74.000000  74.000000   74.000000    74.000000      74.000000
# mean   1102.351351  48.021892  302.945946    20.956216      22.258378
# std      95.658702  14.181385   98.547797     6.423714       9.960468
# min    1006.000000  13.440000   72.000000     6.150000       0.000000
# 25%    1024.250000  39.305000  264.000000    17.045000      19.480000
# 50%    1042.500000  44.550000  330.000000    21.760000      25.320000
# 75%    1181.750000  52.415000  372.500000    24.502500      29.800000
# max    1271.000000  82.480000  466.000000    37.860000      35.590000
#
#          Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  74.000000       74.000000     74.000000      74.000000     74.000000
# mean    4.102838        4.697568      0.005405       2.050541    632.459459
# std     1.730940        5.791562      0.028148       3.257006    296.165966
# ...

# %%
#Using the cut function on Protein variable divide the whole data into 6 bins
data_bins=df

# %%
data_bins['bins']=pd.cut(data_bins['Protein_(g)'],6, labels =["A", "B", "C","E","F","G"])

# %%
data_bins.head(5)
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 5    1006             CHEESE,BRIE      48.42         334        20.75
# 6    1007        CHEESE,CAMEMBERT      51.80         300        19.80
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          78.30     1.62            2.87           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 5          27.68     2.70            0.45           0.0           0.45  ...
# 6          24.26     3.68            0.46           0.0           0.46  ...
#
#    Magnesium_(mg)  Phosphorus_(mg)  Potassium_(mg)  Sodium_(mg)  Zinc_(mg)  \
# ...

# %%
data_bins["bins"].value_counts()
# Out:
# A    480
# B     92
# C     17
# E      5
# G      4
# F      0
# Name: bins, dtype: int64

# %%
data_bins.groupby("bins").describe().T
# Out:
# bins                    A            B            C            E    F  \
# NDB_No count   480.000000    92.000000    17.000000     5.000000  0.0
#        mean   2510.747917  1562.706522  1127.647059  1171.600000  NaN
#        std    1058.594959   782.230392    76.153579    47.574153  NaN
#        min    1001.000000  1006.000000  1023.000000  1133.000000  NaN
#        25%    1235.750000  1042.750000  1091.000000  1134.000000  NaN
# ...                   ...          ...          ...          ...  ...
# EPW    min       4.705882     5.985748     4.471831     7.920000  NaN
#        25%      21.406003    13.257420    10.011062     8.000000  NaN
#        50%      35.977337    15.735995    10.961437     8.991468  NaN
#        75%      61.904762    19.064957    13.854411    12.320499  NaN
#        max            inf    36.061026    19.892953    12.767283  NaN
#
# bins                    G
# NDB_No count     4.000000
#        mean   1175.500000
#        std      57.772542
# ...
